# %%
import pandas as pd
data1 = pd.DataFrame(columns=['Issue', 'Date', 'District', 'Issue in Detail'])
data1.to_csv('Education.csv', index=False)
data2 = pd.DataFrame(columns=['Issue', 'Date', 'District', 'Issue in Detail'])
data2.to_csv('Infrastructure.csv', index=False)
data3 = pd.DataFrame(columns=['Issue', 'Date', 'District', 'Issue in Detail'])
data3.to_csv('WaterSupply.csv', index=False)
data4 = pd.DataFrame(columns=['Issue', 'Date', 'District', 'Issue in Detail'])
data4.to_csv('Sanitation.csv', index=False)
data5 = pd.DataFrame(columns=['Issue', 'Date', 'District', 'Issue in Detail'])
data5.to_csv('HealthCareSystem.csv', index=False)
data6 = pd.DataFrame(columns=['Issue', 'Date', 'District', 'Issue in Detail'])
data6.to_csv('WasteRelatedIssue.csv', index=False)
data7 = pd.DataFrame(columns=['Issue', 'Date', 'District', 'Issue in Detail'])
data7.to_csv('OtherIssue.csv', index=False)

# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd
import csv
# Array to store input strings and answers
inputs = []
filename1='Education.csv'
filename2='Infrastructure.csv'
filename3='WaterSupply.csv'
filename4='Sanitation.csv'
filename5='HealthCareSystem.csv'
filename6='WasteRelatedIssue.csv'
filename7='OtherIssue.csv'
fields = ['Issue', 'Date', 'District', 'Issue in Detail']

def show_input(question):
    question_labe = tk.Label(window, text=' ')
    question_labe.pack()
    question_labe = ttk.Label(window, text=question)
    question_labe.pack()
    question_label = tk.Label(window, text='Enter Date')
    question_label.pack()

    input_entry = tk.Entry(window)
    input_entry.pack()
    
    question_label1 = tk.Label(window, text='Enter your District')
    question_label1.pack()
    
    input_entry1 = tk.Entry(window)
    input_entry1.pack()

    question_label2 = tk.Label(window, text='Enter your Issue')
    question_label2.pack()
    
    input_entry2 = tk.Entry(window)
    input_entry2.pack()
    
    def store_input():
        answer = input_entry.get()
        answer1 = input_entry1.get()
        answer2 = input_entry2.get()
        inputs.append((question, answer, answer1, answer2))
        if(question=='Education'):
            write_to_csv1()
        elif(question=='Infrastructure'):
            write_to_csv2()
        elif(question=='Water Supply'):
            write_to_csv3()
        elif(question=='Sanitation'):
            write_to_csv4()
        elif(question=='Health Care System'):
            write_to_csv5()
        elif(question=='Waste Related Issue'):
            write_to_csv6()
        else:
            write_to_csv7()
        question_labe.pack_forget()
        question_label.pack_forget()
        input_entry.pack_forget()
        question_label1.pack_forget()
        input_entry1.pack_forget()
        question_label2.pack_forget()
        input_entry2.pack_forget()
        submit_button.pack_forget()
#         if len(inputs) > 4:
#             show_options()
#         else:
#             show_restart()

    submit_button = tk.Button(window, text="Submit", command=store_input)
    submit_button.pack()

    
def write_to_csv1():
    with open(filename1, 'a', newline='') as csvfile:
        writer = csv.writer(csvfile)
#         writer.writerow(fields)
        for input_tuple in inputs:
            writer.writerow(input_tuple)
            
def write_to_csv2():
    with open(filename2, 'a', newline='') as csvfile:
        writer = csv.writer(csvfile)
#         writer.writerow(fields)
        for input_tuple in inputs:
            writer.writerow(input_tuple)
            
def write_to_csv3():
    with open(filename3, 'a', newline='') as csvfile:
        writer = csv.writer(csvfile)
#         writer.writerow(fields)
        for input_tuple in inputs:
            writer.writerow(input_tuple)

def write_to_csv4():
    with open(filename4, 'a', newline='') as csvfile:
        writer = csv.writer(csvfile)
#         writer.writerow(fields)
        for input_tuple in inputs:
            writer.writerow(input_tuple)
            
def write_to_csv5():
    with open(filename5, 'a', newline='') as csvfile:
        writer = csv.writer(csvfile)
#         writer.writerow(fields)
        for input_tuple in inputs:
            writer.writerow(input_tuple)
            
def write_to_csv6():
    with open(filename6, 'a', newline='') as csvfile:
        writer = csv.writer(csvfile)
#         writer.writerow(fields)
        for input_tuple in inputs:
            writer.writerow(input_tuple)
    
def write_to_csv7():
    with open(filename7, 'a', newline='') as csvfile:
        writer = csv.writer(csvfile)
#         writer.writerow(fields)
        for input_tuple in inputs:
            writer.writerow(input_tuple)
    
def show_options():
    option1.pack()
    option2.pack()
    option3.pack()
    option4.pack()
    option5.pack()
    option6.pack()
    option7.pack()

# def show_restart():
#     restart_button.pack()
    
# def restart_app():
#     global inputs
#     inputs = []
#     show_options()
#     restart_button.pack_forget()

# Create the main window
window = tk.Tk()

# Add the welcome message
welcome_label = tk.Label(window, text="Hi, welcome to IKSHANA. Select your concern below.")
welcome_label.pack()

# Create the option buttons
option1 = tk.Button(window, text="Education", command=lambda: show_input("Education"))
option2 = tk.Button(window, text="Infrastructure", command=lambda: show_input("Infrastructure"))
option3 = tk.Button(window, text="Water Supply", command=lambda: show_input("Water Supply"))
option4 = tk.Button(window, text="Sanitation", command=lambda: show_input("Sanitation"))
option5 = tk.Button(window, text="Health Care System", command=lambda: show_input("Health Care System"))
option6 = tk.Button(window, text="Waste Related Issue", command=lambda: show_input("Waste Related Issue"))
option7 = tk.Button(window, text="Any Other Issue", command=lambda: show_input("Any Other Issue"))

# Create the restart button
# restart_button = tk.Button(window, text="Restart App", command=restart_app)


# Show the options to start with
show_options()

# Start the main event loop
window.mainloop()

# %%
data=pd.read_csv('Education.csv')
data
# Out:
#        Issue      Date District Issue in Detail
# 0  Education  25/04/23   rohini              na
# 1  Education  26/04/23   rohini  not applicable
